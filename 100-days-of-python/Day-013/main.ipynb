# %%
import pandas as pd
import numpy as np

# %%
desired_col_names = ["month_name", "month_str", "view", "views_inc", "watch_time_hrs", "watch_time_inc", "subs", "sub_inc", "revenue", "revenue_inc", "video_count"]
df = pd.read_csv('./../../data/youtube.csv', names=desired_col_names)

# %%
df.head(10)
# Out:
#         month_name month_str    view        views_inc      watch_time_hrs  \
# 0            Month     Month   Views  Views increased  Watch time (hours)
# 1    January, 2023  1/1/2023  44,700                0               2,200
# 2   February, 2023  2/1/2023  44,400             -300               2,100
# 3      March, 2023  3/1/2023  54,900           10,500               2,400
# 4      April, 2023  4/1/2023  51,200           -3,700               2,200
# 5        May, 2023  5/1/2023  52,700            1,500               2,400
# 6       June, 2023  6/1/2023  49,202           -3,498               2,200
# 7       July, 2023  7/1/2023  62,007           12,805               2,200
# 8     August, 2023  8/1/2023  65,989            3,982               2,969
# 9  September, 2023  9/1/2023  57,122           -8,867               2,615
#
#         watch_time_inc         subs                sub_inc  revenue  \
# 0  Watch time increase  Subscribers  Subscribers increased  Revenue
# ...

# %%
# changing the data type for some of the numeric columns
data = df.astype({'video_count': 'string', 'view': 'string'})
data.describe()
# Out:
#        month_name month_str   view        views_inc watch_time_hrs  \
# count          12        12     12               12             12
# unique         12        12     12               12              8
# top         Month     Month  Views  Views increased          2,200
# freq            1         1      1                1              4
#
#        watch_time_inc subs sub_inc  revenue       revenue_inc video_count
# count              12   12      12       12                12          12
# unique             10   11      11       12                12           6
# top                 0  206      -5  Revenue  Revenue Increase           9
# freq                2    2       2        1                 1           4
