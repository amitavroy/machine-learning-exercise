# %% [markdown]
# # Learning Pandas here

# %%
import pandas as pd

# %% [markdown]
# ## Loading CSV data
#
# Pandas gives a great way to consume data from different format like CSV, JSON etc.

# %%
df = pd.read_csv('../../data/stackoverflow/survey_results_public.csv', index_col='ResponseId')
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %% [markdown]
# ## Getting a sense of the data
#
# There are different way to know about the data.

# %%
df.shape
# Out:
# (89184, 83)

# %% [markdown]
# So, we can see that this CSV has
#
# 1. Rows: 89,184
# 2. Columns: 84
#
# When we did a head on the dataframe, we can only see 20 columsn, because by default it gets trimmed.

# %% [markdown]
# Even with this, I am not able to view all the columns.
#
# So, I will confifure the head to show all.

# %%
pd.set_option('display.max_columns', 84)
# df.set_index('ResponseId', inplace=True) # adding the index to the df
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %% [markdown]
# Great, now I am able to view the entire data.
#
# It's time to load the schema and see the questions.
#
# So, I will load the other CSV file that I for in the zip file.

# %%
schema_df = pd.read_csv('../../data/stackoverflow/survey_results_schema.csv', index_col='qid')
schema_df.sort_index(inplace=True)
schema_df.head()
# Out:
#               qname                                           question  \
# qid
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID106       SOComm  Do you consider yourself a member of the Stack...
#
#        force_resp type selector
# qid
# QID1        False   DB       TB
# QID100      False   MC     SAVR
# QID101      False   MC     SAVR
# QID102      False   MC     SAVR
# QID106      False   MC     SAVR

# %% [markdown]
# I am able to load the data. However, I can see that the question has HTML as well.

# %% [markdown]
# # Checking iloc and loc

# %%
schema_df.iloc[[1, 2, 3], 1]
# Out:
# qid
# QID12                                     Browser Meta Info
# QID310    <div><span style="font-size:19px;"><strong>You...
# QID312
# Name: question, dtype: object

# %%
schema_df.iloc[0:10, [0,1,3]]
# Out:
#                    qname                                           question  \
# qid
# QID16                 S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12           MetaInfo                                  Browser Meta Info
# QID310              Q310  <div><span style="font-size:19px;"><strong>You...
# QID312              Q120
# QID1                  S1  <span style="font-size:22px; font-family: aria...
# QID2          MainBranch  Which of the following options best describes ...
# QID127               Age                                What is your age? *
# QID296        Employment  Which of the following best describes your cur...
# QID308        RemoteWork  Which best describes your current work situation?
# QID297  CodingActivities  Which of the following best describes the code...
#
#         type
# qid
# QID16     DB
# QID12   Meta
# QID310    DB
# QID312    MC
# QID1      DB
# QID2      MC
# QID127    MC
# QID296    MC
# QID308    MC
# QID297    MC

# %% [markdown]
# Looking at the iloc feature of DataFrames.

# %%
df.loc[0:4, 'Age':'EdLevel']
# Out:
#                         Age           Employment  \
# ResponseId
# 1           18-24 years old                  NaN
# 2           25-34 years old  Employed, full-time
# 3           45-54 years old  Employed, full-time
# 4           25-34 years old  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                         Remote
# 3           Hybrid (some remote, some in-person)
# 4           Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
# 4                                                       Hobby
#
#                                                  EdLevel
# ResponseId
# ...

# %% [markdown]
# # Analysing data

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %% [markdown]
# Using this, we are able to understand that a significant percentage of users have opted for Hybrid.
#
# In person is very low compared to other two options.

# %%
def clean_years_of_code(value):
    try:
        return float(value)
    except ValueError:
        return None

# %%
df['YearsCode'] = df['YearsCode'].apply(clean_years_of_code)
df['YearsCode'].unique()
# Out:
# array([nan, 18., 27., 12.,  6., 21.,  4.,  5., 20., 14., 10., 15., 11.,
#         3., 24.,  8., 13., 16., 33., 22., 30., 32.,  7., 35., 28., 40.,
#        17., 29., 19.,  9., 38., 26., 34., 25.,  2., 45., 23., 31., 43.,
#         1., 48., 41., 50., 39., 42., 37., 36., 44., 46., 49., 47.])

# %%
df['YearsCode'].value_counts()
# Out:
# YearsCode
# 10.0    6521
# 5.0     5415
# 6.0     4893
# 8.0     4879
# 7.0     4800
# 4.0     4466
# 15.0    4336
# 3.0     4269
# 20.0    4021
# 12.0    3471
# 9.0     3130
# 2.0     2826
# 25.0    2685
# 13.0    2601
# 11.0    2519
# 14.0    2278
# 30.0    2078
# 16.0    1842
# 18.0    1690
# 17.0    1544
# 23.0    1327
# 40.0    1302
# 1.0     1294
# 22.0    1210
# 35.0    1118
# 24.0     959
# 19.0     826
# 21.0     761
# 28.0     715
# 27.0     710
# 26.0     706
# 33.0     496
# 32.0     444
# 38.0     428
# 45.0     360
# 42.0     347
# 34.0     333
# 29.0     324
# 37.0     312
# 36.0     282
# 31.0     272
# 43.0     265
# 39.0     229
# 41.0     227
# 44.0     160
# 50.0     125
# 46.0     101
# 48.0      96
# 47.0      79
# 49.0      42
# Name: count, dtype: int64
